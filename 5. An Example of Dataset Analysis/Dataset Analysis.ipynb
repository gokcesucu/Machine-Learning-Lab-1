# %% [markdown]
# # LAB HOMEWORK 2
# ## Gökce Sucu 264112

# %% [markdown]
# ## EXERCISE 1)
# ## PART A: INTERESTING STATS

# %% [markdown]
# ###  A.1 MAXIMUM SALE

# %% [markdown]
# We will find the store that has the maximum sale recorded and Print id, data and sales on that day. First, we will install the needed packages and then we have to read 'train.csv' file.

# %% [markdown]
# #### A.1.1 Installing the Packages

# %%
import pandas as pd

# %% [markdown]
# #### A.1.2 Reading The File

# %%
train = pd.read_csv('train.csv', low_memory=False)

# %%
train
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %% [markdown]
# #### A.1.3 Store That Has The Maximum Sale

# %%
#finding the maximum sale recorded
maximum_sale = train['Sales'].max()

# %%
train.loc[(train['Sales']==maximum_sale)][['Store','Sales','Date']]
# Out:
#        Store  Sales        Date
# 44393    909  41551  2015-06-22

# %% [markdown]
# ### A.2. MIN AND MAX POSSIBLE COMPETITION DISTANCE

# %% [markdown]
# #### A.2.1 Reading The File

# %%
store = pd.read_csv('store.csv')

# %%
store
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# ...

# %% [markdown]
# #### A.2.2 Min and Maximum Competition Distance

# %%
#minumum competition distance
min_competition_distance = store['CompetitionDistance'].min()

#maximum competition distance
max_competition_distance = store['CompetitionDistance'].max()

# %%
print('Minimum Competition Distance=',min_competition_distance)
print('Maximum Competition Distance=',max_competition_distance)
# Out:
# Minimum Competition Distance= 20.0
# Maximum Competition Distance= 75860.0

# %% [markdown]
# #### A.2.3 The Stores Has Minumum CD

# %%
#the store that has the minimumcompetition distance
store[store['CompetitionDistance']==min_competition_distance][['Store','CompetitionDistance']]
# Out:
#      Store  CompetitionDistance
# 515    516                 20.0

# %% [markdown]
# #### A.2.4 The Stores Have the Maximum CD

# %%
#the store that has maximum competition distance
store[store['CompetitionDistance']==max_competition_distance][['Store','CompetitionDistance']]
# Out:
#      Store  CompetitionDistance
# 452    453              75860.0

# %% [markdown]
# ### A.3 MAXIMUM TIMELINE

# %% [markdown]
# #### A.3.1 Number Of Stores

# %% [markdown]
# To find the number of stores, we would use set function on the Store column.

# %%
#how many store do we have
print('Number of Store=',len(set(train['Store'])))
# Out:
# Number of Store= 1115

# %% [markdown]
# #### A.3.2 Stores Have Ran Promo

# %% [markdown]
# To find the stores have ran promo, we should delete all stores which have 0 values on 'Promo' column.

# %%
#deleting the non-promoted days
stores_have_promo = train[train['Promo']==1]

# %%
stores_have_promo
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1010515   1111          1  2013-01-07   9444        735     1      1
# 1010516   1112          1  2013-01-07  25165       1661     1      1
# 1010517   1113          1  2013-01-07   8984        907     1      1
# 1010518   1114          1  2013-01-07  21237       2962     1      1
# 1010519   1115          1  2013-01-07   6905        471     1      1
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %% [markdown]
# #### A.3.3. Listing The All Stores' Promo Days

# %% [markdown]
# In this part, we would create a list, which contains list of every stores promo days.

# %%
#list of the all stores promo dates
list_of_stores_promo_days =[]
for i in range(1,1116):
    list_of_stores_promo_days.append(stores_have_promo.loc[train['Store']==i,[ 'Store','Date']])
    
print(list_of_stores_promo_days)
# Out:
# [         Store        Date
# 0            1  2015-07-31
# 1115         1  2015-07-30
# 2230         1  2015-07-29
# 3345         1  2015-07-28
# 4460         1  2015-07-27
# ...        ...         ...
# 1004945      1  2013-01-11
# 1006060      1  2013-01-10
# 1007175      1  2013-01-09
# 1008290      1  2013-01-08
# 1009405      1  2013-01-07
#
# [360 rows x 2 columns],          Store        Date
# 1            2  2015-07-31
# 1116         2  2015-07-30
# 2231         2  2015-07-29
# 3346         2  2015-07-28
# 4461         2  2015-07-27
# ...        ...         ...
# 1004946      2  2013-01-11
# 1006061      2  2013-01-10
# 1007176      2  2013-01-09
# 1008291      2  2013-01-08
# 1009406      2  2013-01-07
#
# [360 rows x 2 columns],          Store        Date
# 2            3  2015-07-31
# 1117         3  2015-07-30
# 2232         3  2015-07-29
# 3347         3  2015-07-28
# 4462         3  2015-07-27
# ...        ...         ...
# 1004947      3  2013-01-11
# ...

# %%
#for example:  store 15th's promo days
list_of_stores_promo_days[15]
# Out:
#          Store        Date
# 15          16  2015-07-31
# 1130        16  2015-07-30
# 2245        16  2015-07-29
# 3360        16  2015-07-28
# 4475        16  2015-07-27
# ...        ...         ...
# 1004960     16  2013-01-11
# 1006075     16  2013-01-10
# 1007190     16  2013-01-09
# 1008305     16  2013-01-08
# 1009420     16  2013-01-07
#
# [360 rows x 2 columns]

# %% [markdown]
# #### A.3.4 Listing Promo Timeline Of Each Store

# %%
#listing the time intervals
time_intervals_of_the_promo=[]
for a in range(0,1115):
    time_intervals_of_the_promo.append(( len(list_of_stores_promo_days[a]),f'Store{a+1}'))

# %%
#number of dates that each store has ran promo
time_intervals_of_the_promo
# Out:
# [(360, 'Store1'),
#  (360, 'Store2'),
#  (360, 'Store3'),
#  (360, 'Store4'),
#  (360, 'Store5'),
#  (360, 'Store6'),
#  (360, 'Store7'),
#  (360, 'Store8'),
#  (360, 'Store9'),
#  (360, 'Store10'),
#  (360, 'Store11'),
#  (360, 'Store12'),
#  (286, 'Store13'),
#  (360, 'Store14'),
#  (360, 'Store15'),
#  (360, 'Store16'),
#  (360, 'Store17'),
#  (360, 'Store18'),
#  (360, 'Store19'),
#  (286, 'Store20'),
#  (360, 'Store21'),
#  (286, 'Store22'),
#  (360, 'Store23'),
#  (360, 'Store24'),
#  (360, 'Store25'),
#  (360, 'Store26'),
#  (360, 'Store27'),
#  (360, 'Store28'),
#  (360, 'Store29'),
#  (360, 'Store30'),
#  (360, 'Store31'),
#  (286, 'Store32'),
#  (360, 'Store33'),
#  (360, 'Store34'),
#  (360, 'Store35'),
#  (286, 'Store36'),
#  (360, 'Store37'),
#  (360, 'Store38'),
#  (360, 'Store39'),
#  (360, 'Store40'),
#  (286, 'Store41'),
#  (360, 'Store42'),
#  (360, 'Store43'),
#  (360, 'Store44'),
#  (360, 'Store45'),
#  (286, 'Store46'),
#  (360, 'Store47'),
#  (360, 'Store48'),
# ...

# %% [markdown]
# #### A.3.5 Finding The Maximum Promo Time Interval

# %%
list_of_time_intervals =[]
for i in range(0,1115):
    list_of_time_intervals.append(time_intervals_of_the_promo[i][0])

# %%
max_intervaltime=max(list_of_time_intervals)
print(f'Maximum Promo Time Interval={max_intervaltime}')
# Out:
# Maximum Promo Time Interval=360

# %% [markdown]
# In conclusion, maximum timeline a store has ran a promo is 360 days.

# %% [markdown]
# #### A.3.6 Finding The The Stores that Has Maximum Time Interval

# %% [markdown]
# In this part, we would create list of the stores that have maximum timeline for promo.

# %%
list_of_stores_has_max_interval=[]
for i in range(0,1115):
    if time_intervals_of_the_promo[i][0]==360:
        list_of_stores_has_max_interval.append(i+1)

# %%
print('List Of The Stores That Have Max Timeline For Promo:\n',list_of_stores_has_max_interval)
# Out:
# List Of The Stores That Have Max Timeline For Promo:
# ...

# %% [markdown]
# #### A.3.7 The Dates Did the Promo Covered For Maximum Timeline

# %% [markdown]
# We already found the list of each stores' promo dates and list of stores that have maximum timeline for promo dates. Now, we will combine this two list.

# %%
#list of stores that have maximum timeline for promo dates
list_of_stores_has_max_interval
#list of each stores' promo dates
list_of_stores_promo_days
# Out:
# [         Store        Date
#  0            1  2015-07-31
#  1115         1  2015-07-30
#  2230         1  2015-07-29
#  3345         1  2015-07-28
#  4460         1  2015-07-27
#  ...        ...         ...
#  1004945      1  2013-01-11
#  1006060      1  2013-01-10
#  1007175      1  2013-01-09
#  1008290      1  2013-01-08
#  1009405      1  2013-01-07
#
#  [360 rows x 2 columns],
#           Store        Date
#  1            2  2015-07-31
#  1116         2  2015-07-30
#  2231         2  2015-07-29
#  3346         2  2015-07-28
#  4461         2  2015-07-27
#  ...        ...         ...
#  1004946      2  2013-01-11
#  1006061      2  2013-01-10
#  1007176      2  2013-01-09
#  1008291      2  2013-01-08
#  1009406      2  2013-01-07
#
#  [360 rows x 2 columns],
#           Store        Date
#  2            3  2015-07-31
#  1117         3  2015-07-30
#  2232         3  2015-07-29
#  3347         3  2015-07-28
#  4462         3  2015-07-27
#  ...        ...         ...
# ...

# %%
#creating a list of promo dates of stores that have amximum timeline
list_of_promo_dates_of_stores_have_max_timeline =[]
for x in list_of_stores_has_max_interval:
    list_of_promo_dates_of_stores_have_max_timeline.append(list_of_stores_promo_days[x-1])

# %%
list_of_promo_dates_of_stores_have_max_timeline
# Out:
# [         Store        Date
#  0            1  2015-07-31
#  1115         1  2015-07-30
#  2230         1  2015-07-29
#  3345         1  2015-07-28
#  4460         1  2015-07-27
#  ...        ...         ...
#  1004945      1  2013-01-11
#  1006060      1  2013-01-10
#  1007175      1  2013-01-09
#  1008290      1  2013-01-08
#  1009405      1  2013-01-07
#
#  [360 rows x 2 columns],
#           Store        Date
#  1            2  2015-07-31
#  1116         2  2015-07-30
#  2231         2  2015-07-29
#  3346         2  2015-07-28
#  4461         2  2015-07-27
#  ...        ...         ...
#  1004946      2  2013-01-11
#  1006061      2  2013-01-10
#  1007176      2  2013-01-09
#  1008291      2  2013-01-08
#  1009406      2  2013-01-07
#
#  [360 rows x 2 columns],
#           Store        Date
#  2            3  2015-07-31
#  1117         3  2015-07-30
#  2232         3  2015-07-29
#  3347         3  2015-07-28
#  4462         3  2015-07-27
#  ...        ...         ...
# ...

# %%
#for example: 10=th store has the maximum promo days and this dates:
list_of_promo_dates_of_stores_have_max_timeline[9]
# Out:
#          Store        Date
# 9           10  2015-07-31
# 1124        10  2015-07-30
# 2239        10  2015-07-29
# 3354        10  2015-07-28
# 4469        10  2015-07-27
# ...        ...         ...
# 1004954     10  2013-01-11
# 1006069     10  2013-01-10
# 1007184     10  2013-01-09
# 1008299     10  2013-01-08
# 1009414     10  2013-01-07
#
# [360 rows x 2 columns]

# %% [markdown]
# #### A.3.2.8 Another Way To Find The Stores Has Maximum TimeLine

# %% [markdown]
# Another way, we can define a function when your input is a stores number, gives to tell this store has maximum timeline or not. It also gives the dates.

# %%
def max_timeline_stores_dates(xth_store):
    if xth_store in list_of_stores_has_max_interval:
        print('This stores total promo days 942 and this days \n \n:',list_of_stores_promo_days[xth_store-1])
    else:
        print('This stores total promo days lesser than 942. ')

# %%
#example 13th store:
max_timeline_stores_dates(13)
# Out:
# This stores total promo days lesser than 942.

# %%
#example 2th store:
max_timeline_stores_dates(2)
# Out:
# This stores total promo days 942 and this days
#
# :          Store        Date
# 1            2  2015-07-31
# 1116         2  2015-07-30
# 2231         2  2015-07-29
# 3346         2  2015-07-28
# 4461         2  2015-07-27
# ...        ...         ...
# 1004946      2  2013-01-11
# 1006061      2  2013-01-10
# 1007176      2  2013-01-09
# 1008291      2  2013-01-08
# 1009406      2  2013-01-07
#
# [360 rows x 2 columns]

# %% [markdown]
# ### A.4 DIFFENCE IN THE MEAN OF SALES

# %% [markdown]
# First, we have to find sales with promo and total sales without promo.

# %% [markdown]
# #### A.4.1 The Sales With Promo and Its Mean

# %% [markdown]
# First, we have to find the sales with promo. So we have delete all information about the stores that dont have promo.

# %%
#creating a table which just shows that stores have promo
train.loc[train['Promo']==1]
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1010515   1111          1  2013-01-07   9444        735     1      1
# 1010516   1112          1  2013-01-07  25165       1661     1      1
# 1010517   1113          1  2013-01-07   8984        907     1      1
# 1010518   1114          1  2013-01-07  21237       2962     1      1
# 1010519   1115          1  2013-01-07   6905        471     1      1
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %% [markdown]
# Noe, we should find the sales with promo.

# %%
#sales with promo
sales_with_promo=train.loc[train['Promo']==1,'Sales']
sales_with_promo
# Out:
# 0           5263
# 1           6064
# 2           8314
# 3          13995
# 4           4822
#            ...
# 1010515     9444
# 1010516    25165
# 1010517     8984
# 1010518    21237
# 1010519     6905
# Name: Sales, Length: 388080, dtype: int64

# %% [markdown]
# Finally, we can use the describe function for tables to find mean value.

# %%
sales_with_promo.describe()
# Out:
# count    388080.000000
# mean       7991.152046
# std        3419.025495
# min           0.000000
# 25%        5922.000000
# 50%        7553.000000
# 75%        9603.000000
# max       38722.000000
# Name: Sales, dtype: float64

# %% [markdown]
# or we can calculate the mean by using mean() function.

# %%
#importing the library to use mean() function
from statistics import mean

#translating the sales with promos into list
list_of_sales_with_promo=list(sales_with_promo)

#calculatin mean of the list
mean_of_the_sales_with_promo=mean(list_of_sales_with_promo)

print('Mean Of The Sales with Promo:\n',mean_of_the_sales_with_promo)
# Out:
# Mean Of The Sales with Promo:
#  7991.152045969903

# %% [markdown]
# In conclusion, the mean of sales with promo is 7991

# %% [markdown]
# #### A.4.2 Sales without Promo and Its Mean

# %% [markdown]
# First we have to find the stores which dont have promo.

# %%
#stores that dont have promo
train[train['Promo']==0]
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 5575         1          7  2015-07-26      0          0     0      0
# 5576         2          7  2015-07-26      0          0     0      0
# 5577         3          7  2015-07-26      0          0     0      0
# 5578         4          7  2015-07-26      0          0     0      0
# 5579         5          7  2015-07-26      0          0     0      0
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 5575               0              0
# 5576               0              0
# ...

# %% [markdown]
# Now, we have to find the sales of the stores that dont have promo.

# %%
sales_without_promo = train.loc[train['Promo']==0, 'Sales']
sales_without_promo
# Out:
# 5575       0
# 5576       0
# 5577       0
# 5578       0
# 5579       0
#           ..
# 1017204    0
# 1017205    0
# 1017206    0
# 1017207    0
# 1017208    0
# Name: Sales, Length: 629129, dtype: int64

# %% [markdown]
# Now, we can find the mean of sales without promo by using describe function.

# %%
sales_without_promo.describe()
# Out:
# count    629129.000000
# mean       4406.050805
# std        3442.450020
# min           0.000000
# 25%           0.000000
# 50%        4622.000000
# 75%        6367.000000
# max       41551.000000
# Name: Sales, dtype: float64

# %% [markdown]
# or we can use mean() function to calculate the mean of sales with promo.

# %%
#creating a list of the sales without promo
list_of_sales_without_promo = list(sales_without_promo)

#defining the mean of the sales without promo
mean_of_the_sales_without_promo = mean(list_of_sales_without_promo)

print('Mean of The Sales without Promo:\n', mean_of_the_sales_without_promo)
# Out:
# Mean of The Sales without Promo:
#  4406.050805160786

# %% [markdown]
# #### A.4.3 Diference Between The Means

# %%
#difference between the mean of the sales with and without promu
difference_means= mean_of_the_sales_with_promo-mean_of_the_sales_without_promo

print('The difference of Sales when Offering a Promo or Not:\n',difference_means)
# Out:
# The difference of Sales when Offering a Promo or Not:
#  3585.1012408091174

# %% [markdown]
# ###  A.5 ANOMALITIES

# %% [markdown]
# #### A.5.1 ANOMALITY 1:The Store is Open & No Sales

# %%
train[(train['Sales']==0) & (train['Open']==1)]
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 86825     971          5  2015-05-15      0          0     1      0
# 142278    674          4  2015-03-26      0          0     1      0
# 196938    699          4  2015-02-05      0          0     1      1
# 322053    708          3  2014-10-01      0          0     1      1
# 330176    357          1  2014-09-22      0          0     1      0
# 340348    227          4  2014-09-11      0          0     1      0
# 340860    835          4  2014-09-11      0          0     1      0
# 341795    835          3  2014-09-10      0          0     1      0
# 346232    548          5  2014-09-05      0          0     1      1
# 346734     28          4  2014-09-04      0          0     1      1
# 347669     28          3  2014-09-03      0          0     1      1
# 348604     28          2  2014-09-02      0          0     1      1
# 386065    102          4  2014-07-24      0          0     1      0
# ...

# %% [markdown]
# There are anamolities in data as in where the store was open but had no sales.

# %% [markdown]
# #### A.5.2 ANOMALITY 2: The Store is Closed & There is Promo

# %%
train[(train['Open']==0) & (train['Promo']==1)]
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 291        292          5  2015-07-31      0          0     0      1
# 875        876          5  2015-07-31      0          0     0      1
# 1406       292          4  2015-07-30      0          0     0      1
# 1990       876          4  2015-07-30      0          0     0      1
# 2521       292          3  2015-07-29      0          0     0      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1009916    512          1  2013-01-07      0          0     0      1
# 1009921    517          1  2013-01-07      0          0     0      1
# 1009964    560          1  2013-01-07      0          0     0      1
# 1010166    762          1  2013-01-07      0          0     0      1
# 1010485   1081          1  2013-01-07      0          0     0      1
#
#         StateHoliday  SchoolHoliday
# 291                0              1
# 875                0              1
# ...

# %%
train[(train['SchoolHoliday']==1) & (train['Open']==1)]
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1016776    682          2  2013-01-01   3375        566     1      0
# 1016827    733          2  2013-01-01  10765       2377     1      0
# 1016863    769          2  2013-01-01   5035       1248     1      0
# 1017042    948          2  2013-01-01   4491       1039     1      0
# 1017190   1097          2  2013-01-01   5961       1405     1      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %% [markdown]
# ### A.6 THE MOST SALES AMONG a,b,c

# %% [markdown]
# #### A.6.1 Finding the Types of Store

# %% [markdown]
# First , we should find the which store is what type.

# %%
#creating a list which is consisted of (store, store types) tuples:
tuple_store_stype =[]
for i in range(0,1115):
    tuple_store_stype.append( (store['Store'][i], store['StoreType'][i]       )  )

# %%
#(store, store type)
print('(Store,StoreType)=\n',tuple_store_stype)
# Out:
# (Store,StoreType)=
# ...

# %% [markdown]
# We found the which stores has the which type.

# %% [markdown]
# #### A.6.2 Grouping The Stores According to Types

# %% [markdown]
# Now, we will grouping the stores according to types.

# %%
#all a type stores 
a_type_stores =[]

#all b type stores
b_type_stores =[]

#all c type stores
c_type_stores=[]

#all d type stores
d_type_stores=[]

#creating lists
for i in tuple_store_stype:
    if i[1]=='a':
        a_type_stores.append(i[0])
    elif i[1]=='b':
        b_type_stores.append(i[0])
    elif i[1]=='c':
        c_type_stores.append(i[0])
    elif i[1]=='d':
        d_type_stores.append(i[0])

# %%
print('Stores that are Type a:\n',a_type_stores)
# Out:
# Stores that are Type a:
# ...

# %%
print('Stores that are types b:\n',b_type_stores)
# Out:
# Stores that are types b:
#  [85, 259, 262, 274, 335, 353, 423, 494, 512, 562, 676, 682, 733, 769, 948, 1081, 1097]

# %%
print('Stores that are types c:\n',c_type_stores)
# Out:
# Stores that are types c:
#  [1, 4, 21, 25, 34, 37, 46, 63, 69, 70, 91, 92, 99, 114, 130, 131, 141, 150, 175, 196, 197, 203, 208, 216, 217, 232, 246, 255, 267, 287, 293, 305, 321, 327, 349, 361, 362, 365, 382, 387, 398, 402, 408, 410, 419, 421, 437, 442, 444, 450, 458, 464, 468, 469, 472, 474, 481, 482, 499, 504, 514, 519, 523, 543, 553, 554, 560, 567, 576, 579, 595, 596, 598, 613, 626, 627, 636, 642, 644, 654, 657, 666, 668, 672, 678, 680, 708, 719, 729, 730, 736, 747, 754, 776, 782, 787, 794, 804, 816, 829, 839, 843, 847, 849, 852, 854, 857, 859, 860, 861, 869, 897, 912, 914, 925, 944, 962, 968, 971, 978, 984, 985, 987, 996, 1001, 1006, 1007, 1016, 1017, 1018, 1023, 1024, 1026, 1041, 1043, 1044, 1051, 1055, 1059, 1070, 1074, 1082, 1085, 1093, 1105, 1109, 1110, 1112]

# %%
print('Stores that are types c:\n',d_type_stores)
# Out:
# Stores that are types c:
# ...

# %% [markdown]
# ####  A.6.3 Grouping All Sales According to Store Types

# %%
store_sales = train[['Store','Sales']]
store_sales
# Out:
#          Store  Sales
# 0            1   5263
# 1            2   6064
# 2            3   8314
# 3            4  13995
# 4            5   4822
# ...        ...    ...
# 1017204   1111      0
# 1017205   1112      0
# 1017206   1113      0
# 1017207   1114      0
# 1017208   1115      0
#
# [1017209 rows x 2 columns]

# %%
store_sales_nonzero=store_sales[store_sales['Sales']!=0]
store_sales_nonzero
# Out:
#          Store  Sales
# 0            1   5263
# 1            2   6064
# 2            3   8314
# 3            4  13995
# 4            5   4822
# ...        ...    ...
# 1016776    682   3375
# 1016827    733  10765
# 1016863    769   5035
# 1017042    948   4491
# 1017190   1097   5961
#
# [844338 rows x 2 columns]

# %%
print(a_type_stores)
# Out:
# [2, 3, 5, 6, 7, 8, 9, 10, 11, 12, 14, 16, 17, 19, 22, 24, 27, 28, 30, 32, 33, 36, 39, 40, 42, 44, 47, 48, 51, 53, 55, 58, 59, 61, 62, 65, 67, 68, 71, 72, 73, 74, 78, 79, 81, 82, 83, 84, 86, 87, 88, 89, 90, 93, 95, 96, 102, 104, 105, 106, 107, 109, 110, 112, 116, 117, 119, 121, 122, 123, 124, 125, 129, 133, 134, 136, 137, 138, 139, 140, 142, 144, 145, 148, 152, 153, 156, 157, 161, 163, 164, 165, 166, 167, 168, 170, 171, 172, 173, 174, 176, 177, 179, 181, 183, 186, 187, 190, 191, 193, 195, 198, 200, 204, 205, 206, 207, 209, 211, 212, 218, 219, 220, 222, 226, 227, 233, 235, 236, 237, 238, 240, 243, 245, 248, 251, 253, 256, 257, 258, 260, 263, 264, 265, 266, 268, 269, 270, 271, 272, 273, 276, 278, 282, 283, 285, 286, 290, 292, 294, 295, 296, 297, 300, 301, 303, 304, 306, 307, 308, 310, 311, 314, 315, 319, 320, 322, 324, 325, 328, 329, 330, 331, 332, 333, 336, 338, 339, 340, 341, 344, 345, 346, 348, 351, 355, 357, 358, 360, 363, 364, 374, 375, 376, 377, 378, 380, 381, 383, 384, 388, 389, 
# ...

# %%
a_type_sales = []
b_type_sales = []
c_type_sales = []
d_type_sales = []

#first try
for i in range(0,100000):
    if store_sales_nonzero.iloc[i][0] in a_type_stores:
        a_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in b_type_stores:
        b_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in c_type_stores:
        c_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in d_type_stores:
        d_type_sales.append(store_sales.iloc[i][1])

# %%
for i in range(100000,200000):
    if store_sales_nonzero.iloc[i][0] in a_type_stores:
        a_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in b_type_stores:
        b_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in c_type_stores:
        c_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in d_type_stores:
        d_type_sales.append(store_sales.iloc[i][1])

# %%
for i in range(200000,300000):
    if store_sales_nonzero.iloc[i][0] in a_type_stores:
        a_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in b_type_stores:
        b_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in c_type_stores:
        c_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in d_type_stores:
        d_type_sales.append(store_sales.iloc[i][1])

# %%
for i in range(400000,500000):
    if store_sales_nonzero.iloc[i][0] in a_type_stores:
        a_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in b_type_stores:
        b_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in c_type_stores:
        c_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in d_type_stores:
        d_type_sales.append(store_sales.iloc[i][1])

# %%
for i in range(500000,600000):
    if store_sales_nonzero.iloc[i][0] in a_type_stores:
        a_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in b_type_stores:
        b_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in c_type_stores:
        c_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in d_type_stores:
        d_type_sales.append(store_sales.iloc[i][1])

# %%
for i in range(600000,700000):
    if store_sales_nonzero.iloc[i][0] in a_type_stores:
        a_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in b_type_stores:
        b_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in c_type_stores:
        c_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in d_type_stores:
        d_type_sales.append(store_sales.iloc[i][1])

# %%
for i in range(100000,200000):
    if store_sales_nonzero.iloc[i][0] in a_type_stores:
        a_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in b_type_stores:
        b_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in c_type_stores:
        c_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in d_type_stores:
        d_type_sales.append(store_sales.iloc[i][1])

# %%
for i in range(800000,844338 ):
    if store_sales_nonzero.iloc[i][0] in a_type_stores:
        a_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in b_type_stores:
        b_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in c_type_stores:
        c_type_sales.append(store_sales.iloc[i][1])
    elif store_sales_nonzero.iloc[i][0] in d_type_stores:
        d_type_sales.append(store_sales.iloc[i][1])

# %%
print('a Type:',sum(a_type_sales))
print('b Type:',sum(b_type_sales))
print('c Type:',sum(c_type_sales))
print('d Type:',sum(d_type_sales))
# Out:
# a Type: 2359536541
# b Type: 80451707
# c Type: 582538316
# d Type: 1334731919

# %%
print('The Store Type That Had The Most Sales:\n'
,max((sum(a_type_sales),' A Type'),(sum(b_type_sales),' B Type '),(sum(c_type_sales),'C Type'),  (sum(d_type_sales),'d Type')  ))
# Out:
# The Store Type That Had The Most Sales:
#  (2359536541, ' A Type')

# %% [markdown]
# ## PART B: PLOTTING

# %% [markdown]
# ### B.1. MEAN OF SALES BASED ON MONTHS

# %% [markdown]
# #### B.1.1 Knowledge About Months' Days

# %% [markdown]
# \begin{array}{ |c|c|c| }
# \hline
# 2015 .07: 31\, days   &     2014 .08: 31 \,days    &     2013. 09: 30\, days \\
# 2015. 06: 30 \,days     &   2014 .07: 31 \,days      &   2013 .08: 31\, days\\
# 2015. 05: 31 \,days    &  2014 .06: 30 \,days      &   2013 .07: 31 \,days\\
# 2015. 04: 30 \,days     &  2014 .05: 31\, days       &  2013. 06: 30 \,days\\
# 2015 .03: 31 \,days     &  2014 .04: 30 \,days       &  2013 .05: 31 \,days\\
# 2015 .02: 28 \,days     &  2014 .03: 31 \,days       &  2013 .04: 30\, days\\
# 2015. 01: 31 \,days     &  2014 .02: 28\, days       &  2013 .03: 31 \,days\\
# 2014 .12: 31 \,days     &  2014 .01: 31\, days       &  2013 .02: 28 \,days\\
# 2014 .11: 30 \,days      & 2013 .12: 31 \,days        & 2013 .01: 31 \,days\\
# 2014 .10: 31 \,days      & 2013 .11: 30 \,days         &            \\
# 2014 .09: 30 \,days      & 2013 .10: 31 \,days         &              \\
# \hline
# \end{array}

# %%
sales=train['Sales']

# %%
#31*1115 =34565
fifteen_july = sum(sales[0:34565])/1115

#30*1115=33450
fifteen_june =sum(sales[34565:34565+33450])/1115

#31*1115 =34565
fifteen_may =sum(sales[34565+33450:34565*2+33450])/1115

#30*1115=33450
fifteen_april=sum(sales[34565*2+33450:34565*2+33450*2])/1115

#31*1115 =34565
fifteen_march = sum(sales[34565*2+33450*2:34565*3+33450*2])/1115

#28*1115=31220
fifteen_february = sum(sales[34565*3+33450*2:34565*3+33450*2+31220])/1115

#31*1115 =34565
fifteen_january=sum(sales[34565*3+33450*2+31220:34565*4+33450*2+31220])/1115

#31*1115 =34565
fourteen_december =sum(sales[34565*4+33450*2+31220:34565*5+33450*2+31220])/1115

#30*1115=33450
fourteen_november=sum(sales[34565*5+33450*2+31220:34565*5+33450*3+31220])/1115

#31*1115 =34565
fourteen_october=sum(sales[34565*5+33450*3+31220:34565*6+33450*3+31220])/1115

#30*1115=33450
fourteen_september =sum(sales[34565*6+33450*3+31220:34565*6+33450*4+31220])/1115

#31*1115 =34565
fourteen_august=sum(sales[34565*6+33450*4+31220:34565*7+33450*4+31220])/1115

#31*1115 =34565
fourteen_july=sum(sales[34565*7+33450*4+31220:34565*8+33450*4+31220])/1115

#30*1115=33450
fourteen_june=sum(sales[34565*8+33450*4+31220:34565*8+33450*5+31220])/1115

#31*1115 =34565
fourteen_may=sum(sales[34565*8+33450*5+31220:34565*9+33450*5+31220])/1115

#30*1115=33450
fourteen_april=sum(sales[34565*9+33450*5+31220:34565*9+33450*6+31220])/1115

#31*1115 =34565
fourteen_march=sum(sales[34565*9+33450*6+31220:34565*10+33450*6+31220])/1115

#28*1115=31220
fourteen_february=sum(sales[34565*10+33450*6+31220:34565*10+33450*6+31220*2])/1115

#31*1115 =34565
fourteen_january=sum(sales[34565*10+33450*6+31220*2:34565*11+33450*6+31220*2])/1115

#31*1115 =34565
thirteen_december=sum(sales[34565*11+33450*6+31220*2:34565*12+33450*6+31220*2])/1115

#30*1115=33450
thirteen_november =sum(sales[34565*12+33450*6+31220*2:34565*12+33450*7+31220*2])/1115

#31*1115 =34565
thirteen_october =sum(sales[34565*12+33450*7+31220*2:34565*13+33450*7+31220*2])/1115

#30*1115=33450
thirteen_september =sum(sales[34565*13+33450*7+31220*2:34565*13+33450*8+31220*2])/1115

#31*1115 =34565
thirteen_august=sum(sales[34565*13+33450*8+31220*2:34565*14+33450*8+31220*2])/1115

#31*1115 =34565
thirteen_july=sum(sales[34565*14+33450*8+31220*2:34565*15+33450*8+31220*2])/1115

#30*1115=33450
thirteen_june = sum(sales[34565*15+33450*8+31220*2:34565*15+33450*9+31220*2])/1115

#31*1115 =34565
thirteen_may =sum(sales[34565*15+33450*9+31220*2:34565*16+33450*9+31220*2])/1115

#30*1115=33450
thirteen_april =sum(sales[34565*16+33450*9+31220*2:34565*16+33450*10+31220*2])/1115

#31*1115 =34565
thirteen_march =sum(sales[34565*16+33450*10+31220*2:34565*17+33450*10+31220*2])/1115

#28*1115=31220
thirteen_february =sum(sales[34565*17+33450*10+31220*2:34565*17+33450*10+31220*3])/1115

#31*1115 =34565
thirteen_january=sum(sales[34565*17+33450*10+31220*3:34565*18+33450*10+31220*3])/1115

# %%
months = [fifteen_july,fifteen_june,fifteen_may ,fifteen_april,fifteen_march ,
          fifteen_february,fifteen_january,fourteen_december ,fourteen_november,
          fourteen_october,fourteen_september,fourteen_august,fourteen_july,fourteen_june,
          fourteen_may,fourteen_april,fourteen_march,fourteen_february,fourteen_january,
          thirteen_december,thirteen_november ,thirteen_october ,thirteen_september ,thirteen_august,
          thirteen_july,thirteen_june,thirteen_may,thirteen_april,thirteen_march,
          thirteen_february ,thirteen_january

]

months.reverse()

# %%
import matplotlib.pyplot as plt
plt.plot(months)
plt.ylabel('mean of sales (monthly)')
plt.show()

# %% [markdown]
# ### B.2 MEAN OF SALES BASED ON DAYS

# %%
daily_sales=[]
n = 0
while n<1017209:
    daily_sales.append(sum(sales[n:n+1115])/1115)
    n=n+1115
daily_sales.reverse()

# %%
print(daily_sales)
# Out:
# [9.373991031390135, 1951.483408071749, 6057.287892376682, 5767.3443946188345, 5754.469058295964, 3780.0233183856503, 3017.7273542600897, 9151.556950672646, 7574.086098654709, 6958.27533632287, 7009.833183856502, 6654.145291479821, 3825.7946188340807, 1700.6412556053813, 5177.837668161435, 4887.093273542601, 4766.332735426009, 5037.543497757848, 5446.6080717488785, 3808.772197309417, 2475.2125560538116, 7738.937219730941, 7289.836771300448, 6869.979372197309, 6761.615246636771, 6452.224215246637, 3713.914798206278, 1688.5174887892376, 5163.602690582959, 5008.531838565023, 5599.8798206278025, 6372.365022421524, 6329.881614349776, 4313.554260089686, 2908.7058295964125, 8851.263677130044, 7726.895964125561, 7089.479820627803, 6815.878923766816, 6627.454708520179, 3926.4708520179374, 1603.4224215246636, 4985.59730941704, 5135.474439461884, 5599.728251121076, 5710.694170403587, 5561.051121076233, 3929.481614349776, 2996.141704035874, 8863.966816143498, 7107.9354260089685, 6911.398206278027
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(daily_sales)
plt.ylabel('mean of sales (daily)')
plt.show()

# %% [markdown]
# ### B.3. CUMULATIVE SALES FOR FIRST STORE

# %%
#store 1 information table
store_one = train[train['Store']==1]

# %%
#store 1 one year information table
store_one_reverse=store_one.iloc[::-1,]

# %%
store_one_a_year =store_one_reverse.iloc[:365,]

# %%
store_one_sales_a_year=store_one_a_year['Sales']

# %%
store_one_sales_a_year.iloc[1]
# Out:
# 5530

# %%
#cumulative sales

cumulative_sales=[]
a=0

for i in range(0,store_one_sales_a_year.shape[0]):
    a = store_one_sales_a_year.iloc[i]+a
    cumulative_sales.append(a)

# %%
print(cumulative_sales)
# Out:
# [0, 5530, 9857, 14343, 19340, 19340, 26516, 32096, 37567, 42459, 47340, 52292, 52292, 57009, 60909, 64917, 68961, 73088, 78270, 78270, 83664, 89384, 94962, 100157, 105743, 111341, 111341, 115396, 119121, 123722, 128431, 134064, 140034, 140034, 147066, 153115, 159255, 164754, 170435, 175805, 175805, 180214, 184229, 188481, 192722, 197531, 203685, 203685, 210092, 215478, 221138, 226399, 231399, 236636, 236636, 240674, 244468, 249026, 253702, 258313, 263663, 263663, 271338, 277638, 283611, 289248, 295101, 300679, 300679, 305628, 309481, 313822, 318930, 323855, 328858, 328858, 335930, 342493, 348091, 353270, 358776, 364379, 364379, 371108, 377794, 384454, 391739, 391739, 398871, 398871, 398871, 404355, 408980, 413273, 417663, 422738, 422738, 428784, 434298, 439201, 443567, 448830, 453603, 453603, 457544, 460901, 464550, 467502, 471805, 476155, 476155, 481827, 486319, 490628, 494567, 499408, 505134, 505134, 510955, 516880, 516880, 523366, 529393, 535305, 535305, 539873, 544497, 549727, 54
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(cumulative_sales)
plt.ylabel('cumulative sales (first year)')
plt.show()

# %% [markdown]
# ###  B.4.Plotting

# %% [markdown]
# #### B.4.1 Customer vs Sales

# %%
plt.title('Customer vs- Sales(2)')
plt.plot(train['Customers'][:100], train['Sales'][:100])

# %% [markdown]
# #### B.4.2 CompetitionDistance vs Sales

# %%
plt.title('CompetitionDistance vs- Sales(2)')
plt.plot(store['CompetitionDistance'], train['Sales'][:1115])

# %% [markdown]
# #### B.4.3 Pearson Correlation Between All Features

# %%
merged = pd.concat([train.iloc[:1115,:],store])
merged.corr()
# Out:
#                               Store  DayOfWeek     Sales  Customers      Open  \
# Store                      1.000000        NaN  0.007593   0.037586 -0.003424
# DayOfWeek                       NaN        NaN       NaN        NaN       NaN
# Sales                      0.007593        NaN  1.000000   0.812378  0.123591
# Customers                  0.037586        NaN  0.812378   1.000000  0.094948
# Open                      -0.003424        NaN  0.123591   0.094948  1.000000
# Promo                           NaN        NaN       NaN        NaN       NaN
# SchoolHoliday              0.018009        NaN  0.058762   0.139971 -0.018599
# CompetitionDistance       -0.027220        NaN       NaN        NaN       NaN
# CompetitionOpenSinceMonth -0.050319        NaN       NaN        NaN       NaN
# CompetitionOpenSinceYear  -0.004648        NaN       NaN        NaN       NaN
# Promo2                     0.007486        NaN       NaN        NaN       NaN
# ...

# %%
train.corr()
# Out:
#                   Store  DayOfWeek     Sales  Customers      Open     Promo  \
# Store          1.000000  -0.000008  0.005126   0.024325 -0.000047  0.000058
# DayOfWeek     -0.000008   1.000000 -0.462125  -0.386445 -0.528963 -0.392925
# Sales          0.005126  -0.462125  1.000000   0.894711  0.678472  0.452345
# Customers      0.024325  -0.386445  0.894711   1.000000  0.616768  0.316169
# Open          -0.000047  -0.528963  0.678472   0.616768  1.000000  0.295042
# Promo          0.000058  -0.392925  0.452345   0.316169  0.295042  1.000000
# SchoolHoliday  0.000641  -0.205388  0.085124   0.071568  0.086171  0.067483
#
#                SchoolHoliday
# Store               0.000641
# DayOfWeek          -0.205388
# Sales               0.085124
# Customers           0.071568
# Open                0.086171
# Promo               0.067483
# SchoolHoliday       1.000000

# %%
store.corr()
# Out:
#                               Store  CompetitionDistance  \
# Store                      1.000000            -0.027220
# CompetitionDistance       -0.027220             1.000000
# CompetitionOpenSinceMonth -0.050319            -0.059126
# CompetitionOpenSinceYear  -0.004648             0.025124
# Promo2                     0.007486            -0.145717
# Promo2SinceWeek            0.007584            -0.060552
# Promo2SinceYear            0.039640            -0.109504
#
#                            CompetitionOpenSinceMonth  \
# Store                                      -0.050319
# CompetitionDistance                        -0.059126
# CompetitionOpenSinceMonth                   1.000000
# CompetitionOpenSinceYear                   -0.052250
# Promo2                                     -0.011485
# Promo2SinceWeek                            -0.035504
# Promo2SinceYear                             0.047815
#
#                            CompetitionOpenSinceYear    Promo2  \
# ...

# %% [markdown]
# #### 5.4.4 Boxplots of First 10 Stores

# %%
sales_of_10_stores=[]
for i in range(0,10):
    sales_of_10_stores.append(train[train['Store']==i][['Sales','Store']])

# %%
for i in range(0,10):
    print(train[train['Store']==i][['Store','Sales']].boxplot())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # EXERCISE 2: LINEAR REGRESSION

# %% [markdown]
# ## PART A: IMPLEMENTING GAUSSIAN ELIMINATION

# %%
#needed packages
import random
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ### A.1 GENERATE MATRIX X

# %%
#mean=2 and sigma=0.01
x = np.random.normal(2, 0.01, 1000).reshape(100,10)
#checking the created matrix's dimension
print('Dimension of x :\n',x.shape)
# Out:
# Dimension of x :
#  (100, 10)

# %% [markdown]
# ### A.2. GENERATE MATRIX Y

# %%
#creating a random matrix with uniform distribution
y =np.random.uniform( 0,10,100).reshape(100,1)

#checking the dimension of created matrrix
print('Dimension of y:\n',y.shape)
# Out:
# Dimension of y:
#  (100, 1)

# %% [markdown]
# ### A.3 LINEAR REGRESSION ALGORITHM

# %% [markdown]
# Now we will use $\beta= (X^TX)^{-1}X^TY$ formula. First we will calculate $A^{-1}=(X^TX)^{-1}$. first we have to add a 1 vector column to x matris for bias.

# %% [markdown]
# #### A.3.1 Adding to 1 column vector to X

# %%
#creating a 1 column vector
one_vector =np.ones((100,1))

X =np.hstack((x,one_vector))
print(X)
# Out:
# [[1.98203965 1.98717043 1.99432386 ... 2.00119053 2.00291333 1.        ]
#  [2.004663   1.98854442 1.98483281 ... 1.98649845 2.00427849 1.        ]
#  [2.01380524 2.00335039 2.0056528  ... 1.98139026 1.99725432 1.        ]
#  ...
#  [2.00055829 2.00586069 1.97439578 ... 2.00473462 1.99446942 1.        ]
#  [1.99738547 1.99839435 2.01878457 ... 2.0001222  1.99769389 1.        ]
#  [1.99414618 2.00193691 1.99495983 ... 2.00582859 2.02190532 1.        ]]

# %% [markdown]
# #### A.3.2 Calculating $(X^TX)^{-1}$

# %%
#transpose of x
X_transpose = np.transpose(X)

#matrix multiplication of x and its transpose
H = np.matmul(X_transpose,X)

#inverse of matrix multiplication of x and its transpose
H_inverse = np.linalg.inv(H)

# %%
H_inverse.shape
# Out:
# (11, 11)

# %% [markdown]
# #### A.3.3 Calculating  $ \beta=(X^TX)^{-1}X^TY$

# %%
#betas
beta_by_lineerreg = np.matmul(np.matmul(H_inverse,X_transpose),y)

# %%
#betas shape
beta_by_lineerreg.shape
# Out:
# (11, 1)

# %%
beta_by_lineerreg
# Out:
# array([[ 44.8044448 ],
#        [  1.57690102],
#        [ 39.38291343],
#        [ -6.19187603],
#        [ -1.84298809],
#        [-40.93187542],
#        [  0.71845975],
#        [-17.75139838],
#        [-21.47344935],
#        [  3.45756743],
#        [  1.15010312]])

# %% [markdown]
# #### A.3.4 Predictions By Lineer Regression Algorithm

# %%
predictions_bylineerreg =np.matmul(X,beta_by_lineerreg)

# %% [markdown]
# #### A:3.4 Plotting By Lineer Regression Algortihm

# %%
plt.title('Prediction Vs Real Values (Linear Regression Algorithm)')
plt.scatter(list(range(100)),y , label="original")
plt.scatter(list(range(100)), predictions_bylineerreg, label="prediction")
plt.legend()
plt.show()

# %% [markdown]
# ### A.4 GAUSSION ELIMINATION

# %% [markdown]
# $AX=b$ and $A$ is an $nxn$ matrix. Then I simply used the algortima which is written on homework:

# %%
def gaussian_elimination(A,b):
    n=A.shape[0]
    z=np.zeros((n,1))
    for k in range(0,n-1):
        for i in range(k+1,n):
            A[i][k]=A[i][k]/A[k][k]
            for j in range(k+1,n):
                A[i][j]=A[i][j]-A[i][k]*A[k][j]
                
    #forword elimination
    for k in range(0,n-1):
        for i in range(k+1,n):
            b[i]=b[i]-A[i][k]*b[k]
        
    #backward solve
    for h in range(0,n):
        i=n-1-h
        s=b[i]
        for j in range(i+1,n):
            s=s-A[i][j]*z[j]
        z[i]=s/A[i][i]
    return z

# %% [markdown]
# ### A.5 IMPLEMENTATION OF GAUSSIAN ELIMINATION

# %% [markdown]
# #### A.5.1 Finding Beta by Using Gaussian Elimination Method

# %%
b_matrix = np.matmul(np.transpose(X),y)

# %%
beta_by_gaussian = gaussian_elimination(H,b_matrix)

# %%
print(beta_by_gaussian)
# Out:
# [[ 44.8044448 ]
#  [  1.57690102]
#  [ 39.38291343]
#  [ -6.19187603]
#  [ -1.84298809]
#  [-40.93187542]
#  [  0.71845975]
#  [-17.75139838]
#  [-21.47344935]
#  [  3.45756743]
#  [  1.15010312]]

# %% [markdown]
# #### A.5.2 Predictions By Gaussian Elimination Function

# %%
predictions_by_gaussian = np.matmul(X,beta_by_gaussian)

# %% [markdown]
# ### A.6 PLOTTING BY GAUSSION ELIMINATION

# %%
plt.title('Prediction Vs. Real Dat (By Gaussian Elimination)')
plt.scatter(list(range(100)),y , label="original")
plt.scatter(list(range(100)), predictions_by_gaussian, label="prediction")
plt.legend()
plt.show()

# %% [markdown]
# ### A.7 PREDICTION BY np.linalg.lstsp

# %%
beta_by_nplinalg=np.linalg.lstsq(X,y,rcond=None)
beta_by_nplinalg[0]
# Out:
# array([[ 44.8044448 ],
#        [  1.57690102],
#        [ 39.38291343],
#        [ -6.19187603],
#        [ -1.84298809],
#        [-40.93187542],
#        [  0.71845975],
#        [-17.75139838],
#        [-21.47344935],
#        [  3.45756743],
#        [  1.15010312]])

# %%
prediction_by_nplinalg =np.matmul(X,beta_by_nplinalg[0])

# %% [markdown]
# #### A.7. Plotting By np.linalg.lstsp

# %%
plt.title('Prediction Vs. Real Data By np.linalg.lstsp')
plt.scatter(list(range(100)),y , label="original")
plt.scatter(list(range(100)), prediction_by_nplinalg, label="prediction")
plt.legend()
plt.show()

# %% [markdown]
# ## PART B: MULTIPLE LINEAR (AUTO) REGRESSION

# %% [markdown]
# ### a. The Stores That Have 942 Days Record

# %%
#REMOVING THE STORES THT DONT HAVE 942 DAYS SALES RECORD
stores_942 =[]

#we are looking for in the 1000 stores that do not have 942 days sale record.
for i in range(0,1115):
    a =train.loc[train['Store']==i,'Sales']
    if len(a)==942:
        stores_942.append(train[train['Store']==i][['Store','Sales']])

# %%
len(stores_942)
# Out:
# 933

# %% [markdown]
# There 933 store that have 942 days record.

# %%
stores_942[1]
# Out:
#          Store  Sales
# 1            2   6064
# 1116         2   5567
# 2231         2   6402
# 3346         2   5671
# 4461         2   6627
# ...        ...    ...
# 1011636      2   2342
# 1012751      2   4484
# 1013866      2   4159
# 1014981      2   4422
# 1016096      2      0
#
# [942 rows x 2 columns]

# %% [markdown]
# ### b. Create A Data Matrix

# %%
sales_of_942=[]
for i in range(0,933):
    sales_of_942.append(stores_942[i]['Sales'])

# %%
#row store, column day
data_matrix=np.array(sales_of_942)
print(data_matrix)
# Out:
# [[ 5263  5020  4782 ...  4327  5530     0]
#  [ 6064  5567  6402 ...  4159  4422     0]
#  [ 8314  8977  7610 ...  5902  6823     0]
#  ...
#  [ 9626  9652  9179 ...  8716 10797     0]
#  [ 7289  7491  6640 ...  5563  6218     0]
#  [27508 24395 25840 ... 18463 20642     0]]

# %% [markdown]
# ### c.1.Training

# %%
#first 800 store and first 900 days
X_train = data_matrix[:800,42:]

#first 800 store and last 42 days
Y_train=data_matrix[:800,:42]

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (800, 900)
# (800, 42)

# %% [markdown]
# ### c.2 Test

# %%
#rest of stores and first 900 days
X_test=data_matrix[800:,42:]

#rest of stores and öast42 days
Y_test=data_matrix[800: , :42]

# %%
print(X_test.shape)
print(Y_test.shape)
# Out:
# (133, 900)
# (133, 42)

# %% [markdown]
# ### d. Model

# %%
X_train
# Out:
# array([[4202, 4645, 4000, ..., 4327, 5530,    0],
#        [4926, 5154, 6924, ..., 4159, 4422,    0],
#        [8074, 7537, 8524, ..., 5902, 6823,    0],
#        ...,
#        [3357, 3478, 3618, ..., 4059, 4072,    0],
#        [8073, 8042, 9478, ..., 5977, 6854,    0],
#        [4142, 4234, 3999, ..., 5320, 5826,    0]], dtype=int64)

# %%
Y_train
# Out:
# array([[ 5263,  5020,  4782, ...,  3846,     0,  4097],
#        [ 6064,  5567,  6402, ...,  4123,     0,  3020],
#        [ 8314,  8977,  7610, ...,  5840,     0,  3891],
#        ...,
#        [ 4833,  3894,  3172, ...,  2822,     0,  1646],
#        [11276,  8711,  8689, ...,  6843,     0,  5085],
#        [ 4357,  3789,  3755, ...,  4087,     0,  2838]], dtype=int64)

# %% [markdown]
# ### d.1 Linear Regression Functin

# %% [markdown]
# Now we will use $\beta= (X^TX)^{-1}X^TY$ formula to find betas.

# %%
#creating a function that calculates linear regression
def lin_reg(X,Y):
    A_inverse = np.linalg.inv(np.matmul(np.transpose(X),X))
    beta= np.matmul(np.matmul(A_inverse,np.transpose(X)),Y)
    return beta

# %% [markdown]
# My computer could not run this function, for this reason i uses linalg.lstsq

# %%
#creating a list of full of betas(consists of 900 parameter)
beta_42=[]
for i in range(0,42):
    beta_42.append(np.linalg.lstsq(X_train,Y_train[:,i],rcond=None)[0])

# %%
len(beta_42)
# Out:
# 42

# %% [markdown]
# beta_42 list of all parameters for each days prediction. So we have 42 different model for each days prediciton.

# %% [markdown]
# ### e. Verifying  Betas dimensions

# %%
len(beta_42[1])
# Out:
# 900

# %% [markdown]
# Now we can make predictions,

# %%
#predictions for each day
predictions_each_day =[]
for i in range(0,42):
    predictions_each_day.append(np.matmul(X_test,beta_42[i]))

# %%
#example first day prediction is:
predictions_each_day[0]
# Out:
# array([  7100.33939591,   6456.69354737,   4861.12731812,  11600.31523338,
#         16443.17105837,  10317.01959573,  14325.03573081,   4097.90399421,
#          3039.54880154,   4442.89915368,   -665.44823257,    904.39380609,
#         -4827.04947994,  21058.27609019,   9363.65258576,  11506.18193902,
#          8006.25001299,  10704.61552533,  17836.8112336 ,  -5512.56684024,
#           893.04829268,   9863.64720386,  33242.32932835,  -2481.29844439,
#          9084.85846971,  -2607.59592843,  17027.61612351,  10086.38128349,
#         16332.6395216 ,   6192.10224209,  18566.45218127,   8154.97482292,
#          8575.05295448,  22076.21375976,   4665.89310233,   5190.29630423,
#         17772.67787999,   3800.08407616,   6476.9315138 ,  -2156.58423309,
#          1559.78092215,  10280.6961318 ,  19892.63727221,   8302.58729173,
#          2416.83661223,   5928.52356502,   4276.63726897,  17854.99904341,
# ...

# %% [markdown]
# ### f. RMSE and MAE

# %%
#example
first_day_predicition=np.matmul(X_test,beta_42[0])
second_day_prediction=np.matmul(X_test,beta_42[1])

# %% [markdown]
# #### f.1. 42 days prediction by using d 42 different betas

# %%
daily_prediction_42=[]
for i in range(0,42):
    daily_prediction_42.append(np.matmul(X_test,beta_42[i]))

# %%
#example: first day prediction of each store (133 store)
daily_prediction_42[0]
# Out:
# array([  7100.33939591,   6456.69354737,   4861.12731812,  11600.31523338,
#         16443.17105837,  10317.01959573,  14325.03573081,   4097.90399421,
#          3039.54880154,   4442.89915368,   -665.44823257,    904.39380609,
#         -4827.04947994,  21058.27609019,   9363.65258576,  11506.18193902,
#          8006.25001299,  10704.61552533,  17836.8112336 ,  -5512.56684024,
#           893.04829268,   9863.64720386,  33242.32932835,  -2481.29844439,
#          9084.85846971,  -2607.59592843,  17027.61612351,  10086.38128349,
#         16332.6395216 ,   6192.10224209,  18566.45218127,   8154.97482292,
#          8575.05295448,  22076.21375976,   4665.89310233,   5190.29630423,
#         17772.67787999,   3800.08407616,   6476.9315138 ,  -2156.58423309,
#          1559.78092215,  10280.6961318 ,  19892.63727221,   8302.58729173,
#          2416.83661223,   5928.52356502,   4276.63726897,  17854.99904341,
# ...

# %% [markdown]
# #### f.2 Error between prediction and Real Values

# %%
error_42 =np.ones((133,42))
for i in range(0,42):
    for j in range(0,133):
        error_42[j][i]=Y_test[j][i]-daily_prediction_42[i][j]

# %%
#error matris
error_42
# Out:
# array([[ 3.60766060e+03,  1.94886477e+03,  2.31983484e+03, ...,
#         -1.76913782e+03,  2.97397604e-11, -2.22182197e+03],
#        [ 2.62430645e+03,  5.37283507e+03,  5.55708569e+03, ...,
#         -1.06936335e+03, -4.12328056e-12, -3.14523024e+03],
#        [ 4.06487268e+03,  4.86518246e+03,  2.31951168e+02, ...,
#         -2.15114582e+03,  5.46860470e-11,  7.49220945e+03],
#        ...,
#        [-6.31457427e+03, -8.50773695e+03, -2.58961982e+03, ...,
#         -4.04028578e+03, -1.28666408e-10,  3.07822488e+03],
#        [ 6.64747015e+02, -1.13264001e+02, -4.40727319e+03, ...,
#         -1.81299895e+03, -5.60521660e-12, -1.57058824e+03],
#        [-4.04100872e+03, -5.15219754e+03,  1.50195555e+04, ...,
#          1.11501636e+02, -1.96497430e-10, -2.48177206e+03]])

# %%
error_42.shape
# Out:
# (133, 42)

# %% [markdown]
# #### f.3 RMSE

# %%
#rmse of a matric
def rmse(X):
    error=0
    for i in range(0,X.shape[0]):
        for j in range(0,X.shape[1]):
            error=X[i][j]**2+error
    return np.sqrt(error/X.shape[0]*X.shape[1])

# %%
print('RMSE=',rmse(error_42))
# Out:
# RMSE= 205077.16366757796

# %% [markdown]
# #### f.4 MAE

# %%
#mae of a matric
def mae(M):
    error_mae=0
    for i in range(0,M.shape[0]):
        for j in range(0,M.shape[1]):
            error_mae=error_mae+M[i][j]
    return error_mae/M.shape[0]*M.shape[1]

# %%
print('MAE=',mae(error_42))
# Out:
# MAE= 13093.599468557557

# %% [markdown]
# ### h Reason Why not Linear Regression is a good Task

# %% [markdown]
# Because errors are so high.
